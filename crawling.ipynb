# %% [markdown]
# <a href="https://colab.research.google.com/github/junanote/test_deeplearning/blob/master/crawling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen

# %%
from bs4 import BeautifulSoup

# %%
html = urlopen("https://news.sbs.co.kr/news/endPage.do?news_id=N1006424531&plink=STAND&cooper=NAVER")

# %%
bsobject = BeautifulSoup(html,"html.parser")

# %%
for link in bsobject.find_all('a'):
  print(link.text.strip(), link.get('href'))
# Out:
# 뉴스 본문 바로가기 #container
# 전체메뉴 바로가기 #sitemap
# 뉴스 기사 검색창 바로가기 #footer_search_input
#  #banner
# 배너 닫기 None
# SBS뉴스 /news/newsMain.do
# 비디오머그 /news/videoMugList.do?plink=GNB&cooper=SBSNEWS
# 스브스뉴스 /news/subusuNews.do?plink=GNB&cooper=SBSNEWS
# 오디오 뉴스 - 보이스 /news/voice.do?plink=GNB&cooper=SBSNEWS
# 인-잇 /news/contributor.do?plink=GNB&cooper=SBSNEWS
# SBS 뉴스 공식 페이스북 https://www.facebook.com/SBS8news
# SBS 뉴스 공식 트위터 https://twitter.com/sbs8news
# SBS 뉴스 공식 카카오스토리 https://story.kakao.com/_djF8VzJGLUxaazZ4cUEzNFlPYUNTSDE4QQ
# SBS 뉴스 공식 유튜브 https://www.youtube.com/channel/UCkinYTS9IHqOEwR1Sze2JTw
# |SBS https://www.sbs.co.kr/
# |로그인 #loginout
# |회원가입 https://join.sbs.co.kr/join/join.do
# SBS 뉴스 /news/newsMain.do
# 분야별 /news/newsflash.do?plink=GNB&cooper=SBSNEWS
# 다시보기 /news/programMain.do?prog_cd=R1&plink=GNB&cooper=SBSNEWS
# 취재파일 /news/coverageList.do?plink=GNB&cooper=SBSNEWS
# 팟캐스트 /news/podcastList.do?plink=GNB&cooper=SBSNEWS
# 이슈 /news/newsHotIssue.do?plink=GNB&cooper=SBSNEWS
# ...
